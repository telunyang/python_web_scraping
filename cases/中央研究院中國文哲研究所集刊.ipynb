# %%
'''
中央研究院中國文哲研究所
https://www.litphil.sinica.edu.tw/publications/bulletin
'''

'''
匯入套件
'''
# 操作 browser 的 API
from selenium import webdriver

# 處理逾時例外的工具
from selenium.common.exceptions import TimeoutException

# 面對動態網頁，等待某個元素出現的工具，通常與 exptected_conditions 搭配
from selenium.webdriver.support.ui import WebDriverWait

# 搭配 WebDriverWait 使用，對元素狀態的一種期待條件，若條件發生，則等待結束，往下一行執行
from selenium.webdriver.support import expected_conditions as EC

# 期待元素出現要透過什麼方式指定，通常與 EC、WebDriverWait 一起使用
from selenium.webdriver.common.by import By

# 處理下拉式選單的工具
from selenium.webdriver.support.ui import Select

# 加入行為鍊 ActionChain (模擬滑鼠移動、點繫、拖曳、按右鍵出現選單，以及鍵盤輸入文字、按下鍵盤上的按鈕等)
from selenium.webdriver.common.action_chains import ActionChains

# 取得系統時間的工具
from datetime import datetime

# 強制等待 (執行期間休息一下)
from time import sleep

# 整理 json 使用的工具
import json

# 執行 command 的時候用的
import os

# regular expression 工具
import re

# 子處理程序，用來取代 os.system 的功能
import subprocess

# 隨機亂數(整數)
from random import randint

# 格式化字串輸出
from pprint import pprint as pp

# 處理編碼字串轉換
from urllib import parse

'''
[1] Selenium with Python 中文翻譯文檔
參考網頁：https://selenium-python-zh.readthedocs.io/en/latest/index.html
[2] selenium 啓動 Chrome 的進階配置參數
參考網址：https://stackoverflow.max-everyday.com/2019/12/selenium-chrome-options/
[3] Mouse Hover Action in Selenium
參考網址：https://www.toolsqa.com/selenium-webdriver/mouse-hover-action/
參考網址：https://selenium-python.readthedocs.io/api.html#module-selenium.webdriver.common.action_chains
參考網址：https://python-selenium-zh.readthedocs.io/zh_CN/latest/7.2%20%E8%A1%8C%E4%B8%BA%E9%93%BE/
[4] How to select a drop-down menu value with Selenium using Python?
參考網址：https://stackoverflow.com/questions/7867537/how-to-select-a-drop-down-menu-value-with-selenium-using-python
'''

'''設定'''
# 啟動瀏覽器工具的選項
my_options = webdriver.ChromeOptions()
# my_options.add_argument("--headless")                #不開啟實體瀏覽器背景執行
my_options.add_argument("--start-maximized")         #最大化視窗
my_options.add_argument("--incognito")               #開啟無痕模式
my_options.add_argument("--disable-popup-blocking") #禁用彈出攔截
my_options.add_argument("--disable-notifications")  #取消通知
my_options.add_argument('--user-agent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.110 Safari/537.36"')  #請求標頭中的使用者代理資訊


# 建立儲存圖片的資料夾，不存在就新增
folderPath = 'sinica'
if not os.path.exists(folderPath):
    os.makedirs(folderPath)

# 下載路徑 (請先在專案目錄下，建立一個新資料夾 files)
download_path = f"C:\\Users\\Owner\\notebooks\\cases\\{folderPath}"

# 指定 chromedriver 檔案的路徑
my_executable_path = './chromedriver.exe'

# Web Driver 變數
driver = None

# 走訪首頁
url = "https://www.litphil.sinica.edu.tw/publications/bulletin"

# 放置資料的變數
listData = []

# JSON 存檔路徑
json_path = "./中央研究院中國文哲研究所集刊.json"


'''程式區域'''
# web driver 初始化
def init():
    global driver
    
    # 使用 Chrome 的 WebDriver
    driver = webdriver.Chrome( 
        options = my_options, 
        executable_path = my_executable_path
    )
    
# 走訪首頁
def visitHomePage():
    # 進入首頁
    driver.get(url)
    
# 走訪各期頁面 (直接走訪分頁取得期刊連結)
def getMainPageLinks(): 
    try:
        # 互動元素的選擇器
        li_pagination_elms_css_selector = 'ul.pagination > li'
        li_data_elms_css_selector = 'ul.publications > li'
        
        # 等待特定元素出現
        WebDriverWait(driver, 10).until(
            EC.presence_of_element_located(
                (By.CSS_SELECTOR, li_data_elms_css_selector)
            )
        )
        
        # 取得分頁資料
        li_pagination_elms = driver.find_elements(By.CSS_SELECTOR, li_pagination_elms_css_selector)
        for li_pagination in li_pagination_elms:
            # 按下分頁號碼
            li_pagination.click()
            
            # 等待
            sleep( randint(1,5) )
            
            # 取得集刊資料
            li_data_elms = driver.find_elements(By.CSS_SELECTOR, li_data_elms_css_selector)
            for li_data in li_data_elms:
                # metadata 初始化
                num = title = sub_title = link = '';
                
                # 取得屬性，同時取得期號
                bg_image = li_data.find_element(By.CSS_SELECTOR, "div.cover").get_attribute('bg-image')
                regex = r"\/0*(\d+)\/.+?\.(jpg|png)"
                match = re.search(regex, bg_image)
                if match != None:
                    # 期號
                    num = match[1]
                    
                    # 標題 與 期號(文字)
                    div = li_data.find_element(By.CSS_SELECTOR, "div.name.ng-binding")
                    list_text = div.get_attribute('innerText').split("\n")
                    title = list_text[0]
                    sub_title = list_text[1]
                    
                    # 內頁連結
                    link = f"{url}/{num}"
                    
                    # 整合資料
                    listData.append({
                        "title": title,
                        "sub_title": sub_title,
                        "link": link
                    })
    except TimeoutException:
        print("操作逾時")
        close()

# 取得 PDF 連結
def getPdfLinks():
    try:
        for index, _dict in enumerate(listData):
            # 沒有 sub 屬性，則建立，為了放置細節頁的內容
            if "sub" not in listData[index]:
                listData[index]['sub'] = []

                # 過濾出 pdf 連結
                regex = r"https?:\/\/.+\.pdf"

                # 前往期刊細節頁面
                driver.get(_dict['link'])

                # 等待主要元素出現
                WebDriverWait(driver, 10).until(
                    EC.presence_of_element_located(
                        (By.CSS_SELECTOR, "ol a[href$=pdf]")
                    )
                )

                # 取得所有超連結
                a_elms = driver.find_elements(By.CSS_SELECTOR, "ol a[href$=pdf]")
                if len(a_elms) > 0:
                    for a in a_elms:
                        listData[index]['sub'].append({
                            "pdf_title": a.get_attribute('innerText'), # 或是 a.text
                            "pdf_link": a.get_attribute('href')
                        })
                        
                        # 下載檔案名稱
                        str_pdf_name = a.get_attribute('innerText')
                        str_pdf_name = re.sub(r"\s|/|／|:|──|-|\?|《|》", "_", str_pdf_name)
                        str_pdf_name = parse.unquote(str_pdf_name)
                        
                        # 定義下載連結
                        download_link = f"./{folderPath}/{listData[index]['title']}_{listData[index]['sub_title']}_{str_pdf_name}.pdf"
                        
                        # 下載檔案
                        os.system(f'curl "{a.get_attribute("href")}" -o "{download_link}"')

                        print(f"已下載: {download_link}")
                        
                        # 等待
                        sleep( randint(1,3) )
                        
    except TimeoutException:
        print("元素等待逾時…")
        sleep(3)
        close()

# 關閉瀏覽器
def close():
    driver.quit()
    
# 儲存 JSON
def saveToJson():
    global listData
    with open(f"{folderPath}/{json_path}", "w", encoding='utf-8') as fp:
        fp.write( json.dumps(listData, ensure_ascii=False, indent=4) )

# 讀取 JSON
def loadJson():
    global listData
    with open(f"{folderPath}/{json_path}", "r", encoding="utf-8") as fp:
        listData = json.loads( fp.read() )
        
'''執行區域'''
if __name__ == "__main__":
    # 開始
    init()
    visitHomePage()
    getMainPageLinks()
    getPdfLinks()
    close()
    saveToJson()
# Out:
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/58/%E4%B8%AD%E8%8B%B1%E6%96%87%E5%B0%81%E9%9D%A2%E7%9B%AE%E9%8C%84.pdf" -o "./sinica/中國文哲研究集刊_第五十八期_中英文封面目錄___.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/58/58-1-50.pdf" -o "./sinica/中國文哲研究集刊_第五十八期_張宗祥校本_說郛_考實__沈暢_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/58/58-51-88.pdf" -o "./sinica/中國文哲研究集刊_第五十八期_Dwelling_in_the_Image__How_Should_We_Look_at_Pre_modern_Chinese_Mountain_Water_Paintings___宋灝_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/58/58-89-126.pdf" -o "./sinica/中國文哲研究集刊_第五十八期_張栻思想演變問題新探_—以心地工夫意指所向之本體義為考察核心__羅聖堡_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/58/58-127-160.pdf" -o "./sinica/中國文哲研究集刊_第五十八期__穀梁傳_注疏合刻與單疏本相關問題考辨__簡逸光_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/58/58-161-198.pdf" -o "./sinica/中國文哲研究集刊_第五十八期_書評PDF合併下載___.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/57/%E4%B8%AD%E8%8B%B1%E6%96%87%E5%B0%81%E9%9D%A2%E7%9B%AE%E9%8C%84.pdf" -o "./sinica/中國文哲研究集刊_第五十七期_中英文封面目錄___.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/57/57-1-32.pdf" -o "./sinica/中國文哲研究集刊_第五十七期_「懸想」與「神思」_—魯迅、韓松與未完的文學革命__王德威_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/57/57-33-62.pdf" -o "./sinica/中國文哲研究集刊_第五十七期_中國早期中觀哲學的存有論與倫理踅轉__嚴瑋泓_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/57/57-63-102.pdf" -o "./sinica/中國文哲研究集刊_第五十七期_「自律」與「性覺」_—論牟宗三宋明理學判教中的問題意識__曾帆_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/57/57-103-142.pdf" -o "./sinica/中國文哲研究集刊_第五十七期_郭店寫本引_詩_與儒學經典詮釋意義的形成__范麗梅_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/57/57-143-192.pdf" -o "./sinica/中國文哲研究集刊_第五十七期_Just_a_Song__Chinese_Lyrics_from_the_Eleventh_and_Early_Twelfth_Centuries__ZHANG_Chen_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/57/57-143-192.pdf" -o "./sinica/中國文哲研究集刊_第五十七期_Encountering_China__Michael_Sandel_and_Chinese_Philosophy__張忠宏_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/57/57-143-192.pdf" -o "./sinica/中國文哲研究集刊_第五十七期__道家與古之道術___吳冠宏_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/57/57-143-192.pdf" -o "./sinica/中國文哲研究集刊_第五十七期__現代性的想像：從晚清到五四___呂文翠_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/56/%E4%B8%AD%E8%8B%B1%E6%96%87%E5%B0%81%E9%9D%A2%E7%9B%AE%E9%8C%84.pdf" -o "./sinica/中國文哲研究集刊_第五十六期_中英文封面目錄___.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/56/56-1-38.pdf" -o "./sinica/中國文哲研究集刊_第五十六期_「比興」之「比」與「類思維」之聯繫_從「前比興」之「比」到漢代「比類」的探索__陳秋宏_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/56/56-39-70.pdf" -o "./sinica/中國文哲研究集刊_第五十六期_曲當人情_王陽明論正人之道__陳志強_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/56/56-71-100.pdf" -o "./sinica/中國文哲研究集刊_第五十六期_論曾天從「真理自體的純粹形相」__黃文宏_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/56/56-101-148.pdf" -o "./sinica/中國文哲研究集刊_第五十六期_諸橋轍次_詩經研究_與謝无量之盜譯、抄襲及其影響__張文朝_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/56/56-149-180.pdf" -o "./sinica/中國文哲研究集刊_第五十六期_書評PDF合併下載___.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/55/%E4%B8%AD%E8%8B%B1%E6%96%87%E5%B0%81%E9%9D%A2%E7%9B%AE%E9%8C%84.pdf" -o "./sinica/中國文哲研究集刊_第五十五期_中英文封面目錄___.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/55/55-1-39.pdf" -o "./sinica/中國文哲研究集刊_第五十五期_朱子格物說試釋__張亨_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/55/55-41-81.pdf" -o "./sinica/中國文哲研究集刊_第五十五期_A_New_Approach_to_Biography_in_Early_Medieval_China__The_Case_of_Zuo_Si__Zeb_RAFT_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/55/55-83-135.pdf" -o "./sinica/中國文哲研究集刊_第五十五期_陳寅恪論錢謙益「推崇曹能始踰越分量」考辨__嚴志雄_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/55/55-137-171.pdf" -o "./sinica/中國文哲研究集刊_第五十五期_從東亞視域論丁茶山對孟子性善論的解釋及其思想史定位__黃俊傑_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/55/55-173-201.pdf" -o "./sinica/中國文哲研究集刊_第五十五期__山川為證_東亞古典文學現地研究舉隅___蕭麗華_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/55/55-173-201.pdf" -o "./sinica/中國文哲研究集刊_第五十五期__儒家後習俗責任倫理學的理念___周明泉_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/55/55-173-201.pdf" -o "./sinica/中國文哲研究集刊_第五十五期__成聖與家庭人倫：宗教對話脈絡下的明清之際儒學___陳立勝_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/54/54-1-35.pdf" -o "./sinica/中國文哲研究集刊_第五十四期_「北曲雜劇之分期演進」新探__曾永義_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/54/54-37-73+%E7%A9%BA%E7%99%BD1.pdf" -o "./sinica/中國文哲研究集刊_第五十四期_王船山「現量」詩說原論__陳勇_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/54/54-75-113+%E7%A9%BA%E7%99%BD1.pdf" -o "./sinica/中國文哲研究集刊_第五十四期_嬲嫐、愛情與早期共產革命文學_論〈三代之愛〉在蘇聯、日本與中國的跨文化實踐與文學實驗__陳相因_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/54/54-115-152.pdf" -o "./sinica/中國文哲研究集刊_第五十四期_證顯形上心體之「一系」說_論唐君毅言宋明儒學之發展趨向__游騰達_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/54/54-153-182.pdf" -o "./sinica/中國文哲研究集刊_第五十四期__尚書周誥十三篇義證___虞萬里_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/54/54-153-182.pdf" -o "./sinica/中國文哲研究集刊_第五十四期_Confucius_Beyond_the_Analects__李貴生_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/54/54-153-182.pdf" -o "./sinica/中國文哲研究集刊_第五十四期_The_Sinophone_Cinema_of_Hou_Hsiao_hsien__Culture,_Style,_Voice_and_Motion__桑梓蘭_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/54/54%E6%9B%B8%E9%A0%81%E5%B0%81%E9%9D%A2.pdf" -o "./sinica/中國文哲研究集刊_第五十四期_中英文封面目錄___.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/53/53-1-46.pdf" -o "./sinica/中國文哲研究集刊_第五十三期_拆除主幹，拼湊片段——論_斐洲遊記_對於施登萊__顏健富_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/53/53-47-71.pdf" -o "./sinica/中國文哲研究集刊_第五十三期_當代華語思維的跨文化處境及其與中文文字體系的關係__宋灝_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/53/53-73-111.pdf" -o "./sinica/中國文哲研究集刊_第五十三期_永樂朝之前陳澔_禮記集說_的傳播及其相關問題探論__劉柏宏_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/53/53-113-160.pdf" -o "./sinica/中國文哲研究集刊_第五十三期_論韓儒丁若鏞禬說對鄭玄郊禘說之顛覆與重構__許子濱_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/53/53-161-196.pdf" -o "./sinica/中國文哲研究集刊_第五十三期__漢經學史___陳壁生_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/53/53-161-196.pdf" -o "./sinica/中國文哲研究集刊_第五十三期__孫應時的學宦生涯：道學追隨者對南宋中期政局變動的因應___林素芬_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/53/53-161-196.pdf" -o "./sinica/中國文哲研究集刊_第五十三期__清代考據學語境下的戲曲理論___侯淑娟_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/52/52%E5%B0%81%E9%9D%A2%E5%B0%81%E5%BA%95%E6%9B%B8%E8%83%8C.pdf" -o "./sinica/中國文哲研究集刊_第五十二期_中英文封面目錄___.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/52/52-1-43.pdf" -o "./sinica/中國文哲研究集刊_第五十二期_宋元理學家讀書法與「唐宋八大家」的經典化__胡琦_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/52/52-45-78.pdf" -o "./sinica/中國文哲研究集刊_第五十二期_以陽明自蔽其心之自我概念論人之惡__陳士誠_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/52/52-79-117.pdf" -o "./sinica/中國文哲研究集刊_第五十二期_中井竹山_非徵_的徂徠學批判及其意義__陳威瑨_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/52/52-119-167.pdf" -o "./sinica/中國文哲研究集刊_第五十二期__春秋公羊傳注疏_合刻例考__郜積意_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/52/52-%E6%9B%B8%E8%A9%95169-198.pdf" -o "./sinica/中國文哲研究集刊_第五十二期__姿與言：詩國革命新論___須文蔚_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/52/52-%E6%9B%B8%E8%A9%95169-198.pdf" -o "./sinica/中國文哲研究集刊_第五十二期__紅樓夢的補天之恨：國族寓言與遺民情懷___吳逸仙_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/52/52-%E6%9B%B8%E8%A9%95169-198.pdf" -o "./sinica/中國文哲研究集刊_第五十二期_Genuine_Pretending__On_the_Philosophy_of_the_Zhuangzi__蔡妙坤_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/51/51-1-37.pdf" -o "./sinica/中國文哲研究集刊_第五十一期_得其氣韻之美_陸時雍論李白古體詩的詩學意義__張俐盈_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/51/51-39-64.pdf" -o "./sinica/中國文哲研究集刊_第五十一期_親親相隱，正義與儒家倫理中的道德兩難__王慶節_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/51/51-65-94.pdf" -o "./sinica/中國文哲研究集刊_第五十一期_無用與機心的當代意涵_海德格對莊子思想的闡發__鍾振宇_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/51/51-95-118.pdf" -o "./sinica/中國文哲研究集刊_第五十一期_解脫軍_現觀莊嚴論釋_：“kiṃ_khalu_hārasya_vihāreṇa__sālakṣaṇyam”_一句中_“hāra”_與_“vihāra”_涵義的探討__宗玉媺_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/51/51-119-146%E9%A0%81.pdf" -o "./sinica/中國文哲研究集刊_第五十一期_明清經學關聯性的一種考察_論清代官編_詩經_專著徵引明人的詮解及其他__楊晉龍_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/51/51-147-176.pdf" -o "./sinica/中國文哲研究集刊_第五十一期__福音演義：晚清漢語基督教小說的書寫___楊雅惠_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/51/51-147-176.pdf" -o "./sinica/中國文哲研究集刊_第五十一期_Phenomenology_and_Intercultural_Understanding___Toward_a_New_Cultural_Flesh__黃冠閔_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/51/51-147-176.pdf" -o "./sinica/中國文哲研究集刊_第五十一期__荀子的美學___陳景黼_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/50/50-1-36.pdf" -o "./sinica/中國文哲研究集刊_第五十期_翻譯、國族、性別__—晚清女作家湯紅紱翻譯小說的文化譯寫__崔文東_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/50/50-37-183.pdf" -o "./sinica/中國文哲研究集刊_第五十期_宗密_圓覺經大疏_的釋經策略及其心性本體論_的詮釋學轉向__郭朝順_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/50/50-85-100.pdf" -o "./sinica/中國文哲研究集刊_第五十期_田愚論四端七情__李明輝_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/50/50-101-136.pdf" -o "./sinica/中國文哲研究集刊_第五十期_季本_春秋私考_研究__—以對_左傳_的批評為核心__劉德明_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/50/50-137-176.pdf" -o "./sinica/中國文哲研究集刊_第五十期_清代考據學對日本古典文學研究之影響研探__—以木村正辭_萬葉集文字辨證_為中心__金原泰介_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/50/50-177-216b.pdf" -o "./sinica/中國文哲研究集刊_第五十期__文化制度和漢語史___林慶勳_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/50/50-177-216b.pdf" -o "./sinica/中國文哲研究集刊_第五十期__金聖歎史實研究___黃偉豪_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/50/50-177-216b.pdf" -o "./sinica/中國文哲研究集刊_第五十期_Translingual_Narration__Colonial_and_Postcolonial_Taiwanese_Fiction_and_Film__李育霖_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/49/49-1-40.pdf" -o "./sinica/中國文哲研究集刊_第四十九期_見與不見的戰爭――論記體與賦體及劉裕北伐__劉苑如_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/49/49-41-82.pdf" -o "./sinica/中國文哲研究集刊_第四十九期_漢初漢文人心態的轉變及其對詩詞風氣的影響――以康熙十八年（1679）博學鴻儒科為考察中心__王力堅_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/49/49-83-120.pdf" -o "./sinica/中國文哲研究集刊_第四十九期_五行原論與原物理__楊儒賓_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/49/49-121-162.pdf" -o "./sinica/中國文哲研究集刊_第四十九期_何休_公羊_字氏例釋__郜積意_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/49/49-163-200.pdf" -o "./sinica/中國文哲研究集刊_第四十九期_錢穆論兩漢今古文及其相關問題__林惟仁_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/49/49-201-226.pdf" -o "./sinica/中國文哲研究集刊_第四十九期__幻化之龍：兩千年中國歷史變遷中的孔子___林素娟_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/49/49-201-226.pdf" -o "./sinica/中國文哲研究集刊_第四十九期_The_Dao_of_Translation__An_East_West_Dialogue__洪嘉琳_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/49/49-201-226.pdf" -o "./sinica/中國文哲研究集刊_第四十九期__文化貿易：清代至民國時期四堡的書籍交易___翁稷安_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/48/48-1-58.pdf" -o "./sinica/中國文哲研究集刊_第四十八期_大鵬誰屬：解碼〈逍遙遊〉中大鵬隱喻的境界位階__蔡璧名_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/48/48-59-96.pdf" -o "./sinica/中國文哲研究集刊_第四十八期_禘莫盛於灌――由唐寫本_論語_鄭注重探「禘自既灌而往」章的詮解問題__許子濱_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/48/48-97-138.pdf" -o "./sinica/中國文哲研究集刊_第四十八期__詩傳大全_與清代前期_詩經_學關聯性探論__以_四庫全書總目_著錄之專著為對象的考察__楊晉龍_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/48/48-139-168.pdf" -o "./sinica/中國文哲研究集刊_第四十八期_臺北國圖所藏_四庫全書總目_稿本殘卷的編纂時間與文獻價值__夏長樸_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/48/48-168-192.pdf" -o "./sinica/中國文哲研究集刊_第四十八期_The_Resurrected_Skeleton__From_Zhuangzi_to_Lu_Xun__凌筱嶠_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/48/48-168-192.pdf" -o "./sinica/中國文哲研究集刊_第四十八期__合理性之尋求：荀子思想研究論集___王靈康_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/48/48-168-192.pdf" -o "./sinica/中國文哲研究集刊_第四十八期_Chinese_Metaphysics_and_Its_Problems__WEI_Jianguo_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/47/01%E5%9A%B4%E5%BF%97%E9%9B%841-48.pdf" -o "./sinica/中國文哲研究集刊_第四十七期_錢謙益遺著於清代的出版及「典律化」歷程__嚴志雄_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/47/02%E8%B3%B4%E9%8C%AB%E4%B8%8949-90.pdf" -o "./sinica/中國文哲研究集刊_第四十七期__莊子_的養生哲學、倫理政治與主體轉化__賴錫三_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/47/03%E9%99%B3%E5%BF%97%E5%BC%B791-136.pdf" -o "./sinica/中國文哲研究集刊_第四十七期_一念陷溺—─_唐君毅與陽明學者「惡」的理論研究__陳志強_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/47/04%E4%BE%AF%E7%BE%8E%E7%8F%8D137-172.pdf" -o "./sinica/中國文哲研究集刊_第四十七期_明代鄉會試_尚書_義出題考察_—─_以考官出題偏重為主的討論__侯美珍_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/47/05%E5%BC%B5%E6%96%87%E6%9C%9D173-216.pdf" -o "./sinica/中國文哲研究集刊_第四十七期_仁井田好古的_詩經_觀及其對朱熹之批評__張文朝_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/47/06%E6%9B%B8%E8%A9%95217-264.pdf" -o "./sinica/中國文哲研究集刊_第四十七期_India_in_the_Chinese_Imagination__Myth,_Religion,_and_Thought__林佩瑩_.pdf"
# curl "http://www.litphil.sinica.edu.tw/public/publications/bulletin/47/06%E6%9B%B8%E8%A9%95217-264.pdf" -o "./sinica/中國文哲研究集刊_第四十七期_Striking_Beauty__A_Philosophical_Look_at_the_Asian_Martial_Arts__劉一民_.pdf"
# curl "http://www.litphil.sinica.edu.tw/public/publications/bulletin/47/06%E6%9B%B8%E8%A9%95217-264.pdf" -o "./sinica/中國文哲研究集刊_第四十七期__從_五經_到_新五經____陳逢源_.pdf"
# curl "http://www.litphil.sinica.edu.tw/public/publications/bulletin/47/06%E6%9B%B8%E8%A9%95217-264.pdf" -o "./sinica/中國文哲研究集刊_第四十七期__孟子與象山心性學之詮釋意涵___蔡家和_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/46/46-1-29.pdf" -o "./sinica/中國文哲研究集刊_第四十六期_慧業通來不礙塵_從蒼雪讀徹_南來堂詩集_看晚明清初賢首宗南方系的發展歷程__廖肇亨_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/46/46-31-62.pdf" -o "./sinica/中國文哲研究集刊_第四十六期_翻譯「教師」_日系教育小說中受到雙重文化影響的教師典範__陳宏淑_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/46/46-63-99.pdf" -o "./sinica/中國文哲研究集刊_第四十六期_釋「天」__鄭吉雄_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/46/46-101-149.pdf" -o "./sinica/中國文哲研究集刊_第四十六期__呂祖全宗正書__清代北京覺源壇的歷史及其呂祖天仙派信仰__黎志添_.pdf"
# curl "https://www.litphil.sinica.edu.tw/public/publications/bulletin/46/46-151-171.pdf" -o "./sinica/中國文哲研究集刊_第四十六期__荀子禮治思想的淵源與戰國諸子之研究___張子立_.pdf"
# curl "http://www.litphil.sinica.edu.tw/public/publications/bulletin/46/46-151-171.pdf" -o "./sinica/中國文哲研究集刊_第四十六期__「鎔鑄」與「進程」_朱熹_四書章句集注_之歷史思維___林永勝_.pdf"
# curl "http://www.litphil.sinica.edu.tw/public/publications/bulletin/46/46-151-171.pdf" -o "./sinica/中國文哲研究集刊_第四十六期_The_Burden_of_Female_Talent__The_Poet_Li_Qingzhao_and_Her_History_in_China__YANG_Xiaoshan_.pdf"
