# %%
# break
'''
說明
當偵測到字母 t 時，就會強制結束迴圈
'''
count=0
for string in 'content':
    count += 1
    if string == 't':
        break
    print(string, end="")
# Out:
# con

# %%
# continue
'''
說明
當偵測到字母 t 時，
會跳過本次迴圈剩下的程式碼 print(string)，
但不會結束迴圈，仍然會進入下一圈繼續執行
'''
count=0
for string in 'content':
    count += 1
    if string == 't':
        continue
    print(string, end="")
# Out:
# conen

# %%
# pass
'''
說明
當偵測到字母 t 時，會忽略該條件，繼續像正常迴圈一樣運行程序
備註
有時候寫pass，是為了將某塊或某行列入 to-do
'''
count=0
for string in 'content':
    count += 1
    if string == 't':
        pass
    print(string, end="")
# Out:
# content
